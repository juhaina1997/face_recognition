# %%
# %pip install modelscope==1.4.2
# %pip install open_clip_torch
# %pip install pytorch-lightning
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting modelscope==1.4.2
#   Using cached modelscope-1.4.2-py3-none-any.whl.metadata (31 kB)
# Collecting addict (from modelscope==1.4.2)
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: attrs in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from modelscope==1.4.2) (24.1.0)
# Collecting datasets<=2.8.0,>=2.7.0 (from modelscope==1.4.2)
#   Using cached datasets-2.8.0-py3-none-any.whl.metadata (19 kB)
# Collecting einops (from modelscope==1.4.2)
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock>=3.3.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from modelscope==1.4.2) (3.15.4)
# Collecting gast>=0.2.2 (from modelscope==1.4.2)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting jsonplus (from modelscope==1.4.2)
#   Using cached jsonplus-0.8.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting numpy<1.24.0 (from modelscope==1.4.2)
#   Using cached numpy-1.23.5.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/cli/base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/cli/base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/commands/install.py", line 379, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#                             ^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/resolvers.py", line 173, in _add_to_criteria
#     if not criterion.candidates:
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/resolvelib/structs.py", line 156, in __bool__
#     return bool(self._sequence)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 174, in __bool__
#     return any(self)
#            ^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 162, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 53, in _iter_built
#     candidate = func()
#                 ^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 186, in _make_candidate_from_link
#     base: Optional[BaseCandidate] = self._make_base_candidate_from_link(
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 232, in _make_base_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#                                        ^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 303, in __init__
#     super().__init__(
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 158, in __init__
#     self.dist = self._prepare()
#                 ^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 235, in _prepare
#     dist = self._prepare_distribution()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 314, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/operations/prepare.py", line 527, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/operations/prepare.py", line 642, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/operations/prepare.py", line 72, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/distributions/sdist.py", line 56, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/distributions/sdist.py", line 126, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/distributions/sdist.py", line 103, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_internal/utils/misc.py", line 706, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/pyproject_hooks/_impl.py", line 166, in get_requires_for_build_wheel
#     return self._call_hook('get_requires_for_build_wheel', {
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/pyproject_hooks/_impl.py", line 321, in _call_hook
#     raise BackendUnavailable(data.get('traceback', ''))
# pip._vendor.pyproject_hooks._impl.BackendUnavailable: Traceback (most recent call last):
#   File "/Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 77, in _build_backend
#     obj = import_module(mod_path)
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/private/var/folders/2z/nc3g7q953ssdp96bjsh4pl4m0000gp/T/pip-build-env-ecdo5yad/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 10, in <module>
#     import distutils.core
# ModuleNotFoundError: No module named 'distutils'
#
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.29.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: torch>=1.9.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (2.4.0)
# Requirement already satisfied: torchvision in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (0.19.0)
# Requirement already satisfied: regex in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (2024.7.24)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (4.66.5)
# Requirement already satisfied: huggingface-hub in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (0.24.5)
# Requirement already satisfied: safetensors in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (0.4.4)
# Requirement already satisfied: timm in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from open_clip_torch) (1.0.8)
# Requirement already satisfied: filelock in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: networkx in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (2024.6.1)
# Requirement already satisfied: setuptools in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=1.9.0->open_clip_torch) (72.1.0)
# Requirement already satisfied: wcwidth in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: packaging>=20.9 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from huggingface-hub->open_clip_torch) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from huggingface-hub->open_clip_torch) (6.0.1)
# Requirement already satisfied: requests in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: numpy in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torchvision->open_clip_torch) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torchvision->open_clip_torch) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from requests->huggingface-hub->open_clip_torch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from requests->huggingface-hub->open_clip_torch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from requests->huggingface-hub->open_clip_torch) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from requests->huggingface-hub->open_clip_torch) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.3.0)
# Downloading open_clip_torch-2.29.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.1 MB/s eta 0:00:00ta 0:00:01
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Installing collected packages: ftfy, open_clip_torch
# Successfully installed ftfy-6.3.1 open_clip_torch-2.29.0
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from pytorch-lightning) (2.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from pytorch-lightning) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from pytorch-lightning) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from pytorch-lightning) (4.12.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.11.8-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.10.1)
# Requirement already satisfied: setuptools in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (72.1.0)
# Requirement already satisfied: filelock in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.4)
# Requirement already satisfied: sympy in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.1)
# Requirement already satisfied: networkx in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: numpy<2.0,>1.20.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from torchmetrics>=0.7.0->pytorch-lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (24.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /Users/juhainaparvin/Library/Python/3.12/lib/python/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading lightning_utilities-0.11.8-py3-none-any.whl (26 kB)
# Downloading torchmetrics-1.5.1-py3-none-any.whl (890 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.11.8 pytorch-lightning-2.4.0 torchmetrics-1.5.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from modelscope.pipelines import pipeline
from modelscope.outputs import OutputKeys

p = pipeline('text-to-video-synthesis', 'damo/text-to-video-synthesis')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from modelscope.pipelines import pipeline
#       2 from modelscope.outputs import OutputKeys
#       4 p = pipeline('text-to-video-synthesis', 'damo/text-to-video-synthesis')
#
# ModuleNotFoundError: No module named 'modelscope'
